# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mlp
import seaborn as sns

# %%
from google.colab import files
data=files.upload()
# Out:
#      <input type="file" id="files-90cb6df2-fe21-4a68-a525-c3f790ffd81f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-90cb6df2-fe21-4a68-a525-c3f790ffd81f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_excel('Titanic DS.xlsx')
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#       Unnamed: 3     sex      age  sibsp  parch  ticket      fare embarked
# ...

# %%
df.isnull().sum()
# Out:
# pclass           0
# survived         0
# name             0
# Unnamed: 3    1309
# sex              0
# age            263
# sibsp            0
# parch            0
# ticket           0
# fare             1
# embarked         2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df1=df.drop(labels='Unnamed: 3',axis=1)
df1
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare embarked
# ...

# %%
df1.isnull().sum()
# Out:
# pclass        0
# survived      0
# name          0
# sex           0
# age         263
# sibsp         0
# parch         0
# ticket        0
# fare          1
# embarked      2
# dtype: int64

# %%
df2=df1.dropna(subset=['fare','embarked'],how='any')
df2
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare embarked
# ...

# %%
df2.isnull().sum()
# Out:
# pclass        0
# survived      0
# name          0
# sex           0
# age         263
# sibsp         0
# parch         0
# ticket        0
# fare          0
# embarked      0
# dtype: int64

# %%
df2.age.mean()
# Out:
# 29.813199137104508

# %%
df2.age.fillna(df2.age.mean(),inplace=True)
df2
# Out:
# <ipython-input-84-9aaccee46702>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.age.fillna(df2.age.mean(),inplace=True)
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# ...

# %%
df3=df2.replace(to_replace=29.813199137104508,value=29.8)
df3
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare embarked
# ...

# %%
df3.isnull().sum()
# Out:
# pclass      0
# survived    0
# name        0
# sex         0
# age         0
# sibsp       0
# parch       0
# ticket      0
# fare        0
# embarked    0
# dtype: int64

# %%
(df3['survived']==0).sum()
# Out:
# 808

# %%
(df3['survived']==1).sum()
# Out:
# 498

# %%
df3.age.head(50)
# Out:
# 0     29.0000
# 1      0.9167
# 2      2.0000
# 3     30.0000
# 4     25.0000
# 5     48.0000
# 6     63.0000
# 7     39.0000
# 8     53.0000
# 9     71.0000
# 10    47.0000
# 11    18.0000
# 12    24.0000
# 13    26.0000
# 14    80.0000
# 15    29.8000
# 16    24.0000
# 17    50.0000
# 18    32.0000
# 19    36.0000
# 20    37.0000
# 21    47.0000
# 22    26.0000
# 23    42.0000
# 24    29.0000
# 25    25.0000
# 26    25.0000
# 27    19.0000
# 28    35.0000
# 29    28.0000
# 30    45.0000
# 31    40.0000
# 32    30.0000
# 33    58.0000
# 34    42.0000
# 35    45.0000
# 36    22.0000
# 37    29.8000
# 38    41.0000
# 39    48.0000
# 40    29.8000
# 41    44.0000
# 42    59.0000
# 43    60.0000
# 44    41.0000
# 45    45.0000
# 46    29.8000
# 47    42.0000
# 48    53.0000
# 49    36.0000
# Name: age, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
(df3['sex']=='male').sum()
# Out:
# 842

# %%
(df3['sex']=='female').sum()
# Out:
# 464

# %%
(df3['survived']==1).sum()
# Out:
# 498

# %%
(df3['survived']==0).sum()
# Out:
# 808

# %%
df3.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'embarked'],
#       dtype='object')

# %%
def categorical_histogram(df, colname):
  df3.groupby(colname).size().plot(kind='bar')
chart = categorical_histogram(df1,['embarked'])

# %%
def categorical_histogram(df, colname):
  df3.groupby(colname).size().plot(kind='bar')
chart = categorical_histogram(df1,['parch'])

# %%
def categorical_histogram(df, colname):
  df3.groupby(colname).size().plot(kind='bar')
chart = categorical_histogram(df1,['sibsp'])

# %%
def categorical_histogram(df, colname):
  df3.groupby(colname).size().plot(kind='bar')
chart = categorical_histogram(df1,['sex'])

# %%
def categorical_histogram(df, colname):
  df3.groupby(colname).size().plot(kind='pie')
chart = categorical_histogram(df1,['survived','sex'])

# %%
def categorical_histogram(df, colname,figscale=1):
  df3.groupby(colname).size().plot(kind='bar',figsize=(20*figscale, 4*figscale))
chart = categorical_histogram(df1,['age'])

# %%
def categorical_histogram(df, colname):
  df3.groupby(colname).size().plot(kind='bar')
chart = categorical_histogram(df1,['pclass'])

# %%
def categorical_histogram(df, colname,figscale=1):
  df3.groupby(colname).size().plot(kind='pie',figsize=(5*figscale, 5*figscale))
chart = categorical_histogram(df1,['fare'])

# %%
def categorical_histogram(df, colname):
  df3.groupby(colname).size().plot(kind='bar')
chart = categorical_histogram(df1,['survived','sex'])

# %%
def categorical_histogram(df, colname):
  df3.groupby(colname).size().plot(kind='bar')
chart = categorical_histogram(df1,['survived'])
